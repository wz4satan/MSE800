# %% [markdown]
# **First example for underscore: Last Expression in Python.**

# %%
a = 1+5+4
b = 6
c = "ABC"
a
# Out:
# 10

# %% [markdown]
# The last expression is "a = 1+5+4" after you executed the first code line, and the value is "10".

# %%
_
# Out:
# 10

# %%
b
# Out:
# 6

# %%
_
# Out:
# 6

# %%
c
# Out:
# 'ABC'

# %%
_
# Out:
# 'ABC'

# %% [markdown]
# The expression cha

# %% [markdown]
# **Second example for underscore: Ignoring Values**
