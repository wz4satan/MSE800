# %%
x_str = input("Please input a value to the base: ")
y_str = input("Please input a value to the exponent: ")
print(f"{float(x_str)} to the power of {int(y_str)} = {float(x_str) ** int(y_str)}")
# Out:
# Please input a value to the base:  2
# Please input a value to the exponent:  3
# 2.0 to the power of 3 = 8.0
